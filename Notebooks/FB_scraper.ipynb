# %%
import facebook_scraper
import pandas as pd

# %%
from tqdm import tqdm

# %%
posts = facebook_scraper.get_posts('https://www.facebook.com/zomato')

# %%
import time

# %%
post_dict = {"post":[],"comments":[],"comments_count":[]}

# %%
df = pd.DataFrame(post_dict)

# %%
df
# Out:
#                                                  post  \
# 0               The Great Khali’s Epic Cheat Meal 🍕🍔🍟
# 1                                                  ❤️
# 2   happy Raksha Bandhan to the ones we love to ha...
# 3   happy independence day 🧡🤍💚\n\n(we're gladly ta...
# 4                       2 mins after placing an order
# 5                                         manifesting
# 6   MOST unique food in Leh! | Eat Like A Girl ft....
# 7   Our favourite baker, @Bake With Shivesh tells ...
# 8
# 9               I am not the danger, I am in danger 🥴
# 10  Okay so Sahiba is a massive dimsum fan (and al...
# 11  Mcdonald's BTS Menu, Mukbang style!\n\nSahiba ...
# 12  She gives us an on-ground report of everything...
# 13  Have you ever tried buffalo feet soup and brai...
# 14  corporate wants you to order from this place r...
# 15  A deep dive into the college life of Kusha Kap...
# 16               delivering good vibes to everyone <3
# ...

# %%
len(post_dict['comments'])
# Out:
# 751

# %%
from facebook_scraper import get_posts
for post in tqdm(get_posts('zomato', pages=50,options={"comments": True},cookies='facebook.com_cookies.txt')):
    try:
        comments = []
        post_dict['post'].append(post['text'])
        post_dict['comments_count'].append(post['comments'])
        for comment in post['comments_full']:
            comments.append(comment.get('comment_text'))
        post_dict['comments'].append(comments)
        time.sleep(0.5)
        
    except Exception as e:
        print(e)
# Out:
# C:\Users\rahul\AppData\Local\Programs\Python\Python310\lib\site-packages\facebook_scraper\facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# 1it [00:07,  7.91s/it]C:\Users\rahul\AppData\Local\Programs\Python\Python310\lib\site-packages\dateparser\freshness_date_parser.py:76: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   now = self.get_local_tz().localize(now)
# 33it [06:22,  7.01s/it]Traceback (most recent call last):
#   File "C:\Users\rahul\AppData\Local\Programs\Python\Python310\lib\site-packages\facebook_scraper\utils.py", line 279, in safe_consume
#     for item in generator:
# ...

# %%
df_new = pd.DataFrame(post_dict)

# %%
df_new.to_csv('zomato_comments.csv')

# %%
df

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.
